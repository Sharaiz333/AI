# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharaiz333/AI/blob/main/Sharaiz_57288.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruit_list= ["Apple", "Banana", "Grape"]
print(fruit_list)
print(type(fruit_list))
fruit_list
# Out:
# ['Apple', 'Banana', 'Grape']
# <class 'list'>
# ['Apple', 'Banana', 'Grape']

# %%
fruit_list.remove("Mango")

# %%
fruit_list.copy()
fruit_list.count("Mango")
# Out:
# 1

# %%
for i in fruit_list:
  print(i)
# Out:
# Apple
# Banana
# Grape
# Mango

# %%
fruit_list.extend("Banana")

# %%
print(fruit_list)
# Out:
# ['Apple', 'Banana', 'Grape', 'Mango', 'B', 'a', 'n', 'a', 'n', 'a', 'B', 'a', 'n', 'a', 'n', 'a']

# %%
fruit_list.index("Mango")
# Out:
# 3

# %%
fruit_list.insert(5,"Orange")

# %%
print(fruit_list)
# Out:
# ['Apple', 'Banana', 'Grape', 'Mango', 'B', 'Orange', 'Orange', 'a', 'n', 'a', 'n', 'a', 'B', 'a', 'n', 'a', 'n', 'a']

# %%
fruit_list.pop(11)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2522045325.py in <cell line: 0>()
# ----> 1 fruit_list.pop(11)
#
# IndexError: pop index out of range

# %%
print(fruit_list)
# Out:
# ['Apple', 'Banana', 'Grape', 'Mango', 'Orange', 'B', 'a', 'n', 'a', 'n', 'a']

# %%
fruit_list.reverse()

# %%
print(fruit_list)
# Out:
# ['a', 'n', 'a', 'n', 'a', 'B', 'Orange', 'Mango', 'Grape', 'Banana', 'Apple']

# %%
fruit_list.sort()

# %%
print(fruit_list)
# Out:
# ['Apple', 'B', 'Banana', 'Grape', 'Mango', 'Orange', 'a', 'a', 'a', 'n', 'n']

# %%
print(fruit_list)
# Out:
# ['Apple', 'Banana', 'Grape', 'Mango', 'Orange', 'B', 'a', 'a', 'a', 'n', 'n']

# %%
len(fruit_list)
# Out:
# 11
